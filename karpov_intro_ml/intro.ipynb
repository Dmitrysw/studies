# %%
import pandas as pd
import numpy as np

# %%
students_performance = pd.read_csv("E:\code\studies\karpov_intro_ml\StudentsPerformance.csv")
students_performance
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
students_performance.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
students_performance.describe()
# Out:
#        math score  reading score  writing score
# count  1000.00000    1000.000000    1000.000000
# mean     66.08900      69.169000      68.054000
# std      15.16308      14.600192      15.195657
# min       0.00000      17.000000      10.000000
# 25%      57.00000      59.000000      57.750000
# 50%      66.00000      70.000000      69.000000
# 75%      77.00000      79.000000      79.000000
# max     100.00000     100.000000     100.000000

# %%
students_performance.dtypes
# Out:
# gender                         object
# race/ethnicity                 object
# parental level of education    object
# lunch                          object
# test preparation course        object
# math score                      int64
# reading score                   int64
# writing score                   int64
# dtype: object

# %%
students_performance.shape
# Out:
# (1000, 8)

# %%
students_performance.groupby("gender").aggregate({"writing score" : "mean"})
# Out:
#         writing score
# gender
# female      72.467181
# male        63.311203

# %%
students_performance.size
# Out:
# 8000

# %%
students_performance.iloc[0:3, 0:5]
# Out:
#    gender race/ethnicity parental level of education     lunch  \
# 0  female        group B           bachelor's degree  standard
# 1  female        group C                some college  standard
# 2  female        group B             master's degree  standard
#
#   test preparation course
# 0                    none
# 1               completed
# 2                    none

# %%
students_performance[0:5][['gender', 'race/ethnicity', 'parental level of education']]    #из комментов на степике
# Out:
#    gender race/ethnicity parental level of education
# 0  female        group B           bachelor's degree
# 1  female        group C                some college
# 2  female        group B             master's degree
# 3    male        group A          associate's degree
# 4    male        group C                some college

# %%
students_performance.iloc[[0, 3, 10] , 0:5]
# Out:
#     gender race/ethnicity parental level of education         lunch  \
# 0   female        group B           bachelor's degree      standard
# 3     male        group A          associate's degree  free/reduced
# 10    male        group C          associate's degree      standard
#
#    test preparation course
# 0                     none
# 3                     none
# 10                    none

# %%
students_performance.iloc[[0, 3, 10, -1] , 0:5]
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 10     male        group C          associate's degree      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course
# 0                      none
# 3                      none
# 10                     none
# 999                    none

# %%
students_performance_with_names = students_performance.iloc[[0,3,4,5,6]]

# %%
students_performance_with_names
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
# 5  female        group B          associate's degree      standard
# 6  female        group B                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 3                    none          47             57             44
# 4                    none          76             78             75
# 5                    none          71             83             78
# 6               completed          88             95             92

# %%
students_performance_with_names.index = ["Cersei", "Tywin", "Gregor", "Joffrey", "Ilyn Payne"]

# %%
students_performance_with_names
# Out:
#             gender race/ethnicity parental level of education         lunch  \
# Cersei      female        group B           bachelor's degree      standard
# Tywin         male        group A          associate's degree  free/reduced
# Gregor        male        group C                some college      standard
# Joffrey     female        group B          associate's degree      standard
# Ilyn Payne  female        group B                some college      standard
#
#            test preparation course  math score  reading score  writing score
# Cersei                        none          72             72             74
# Tywin                         none          47             57             44
# Gregor                        none          76             78             75
# Joffrey                       none          71             83             78
# Ilyn Payne               completed          88             95             92

# %%
students_performance_with_names.loc[["Cersei", "Joffrey"], ["gender", "math score"]]
# Out:
#          gender  math score
# Cersei   female          72
# Joffrey  female          71

# %%
students_performance_with_names.iloc[:, 0]
# Out:
# Cersei        female
# Tywin           male
# Gregor          male
# Joffrey       female
# Ilyn Payne    female
# Name: gender, dtype: object

# %%
type(students_performance_with_names.iloc[:, 0])
# Out:
# pandas.core.series.Series

# %%
pd.Series([1, 2, 3])
# Out:
# 0    1
# 1    2
# 2    3
# dtype: int64

# %%
my_series1 = pd.Series([1, 2, 3], index = ["Cersei", "Joffrey", "Tywin"])
my_series2 = pd.Series([4, 5, 6], index = ["Cersei", "Joffrey", "Tywin"])

# %%
pd.DataFrame({"name1" : my_series1, "name2": my_series2})
# Out:
#          name1  name2
# Cersei       1      4
# Joffrey      2      5
# Tywin        3      6

# %%
help(pd.pandas.core)
# Out:
# Help on package pandas.core in pandas:
#
# NAME
#     pandas.core
#
# PACKAGE CONTENTS
#     accessor
#     aggregation
#     algorithms
#     api
#     apply
#     array_algos (package)
#     arraylike
#     arrays (package)
#     base
#     common
#     computation (package)
#     config_init
#     construction
#     dtypes (package)
#     flags
#     frame
#     generic
#     groupby (package)
#     index
#     indexers
#     indexes (package)
#     indexing
#     internals (package)
#     missing
#     nanops
#     ops (package)
#     resample
#     reshape (package)
#     series
#     shared_docs
#     sorting
#     sparse (package)
#     strings (package)
#     tools (package)
#     util (package)
#     window (package)
#
# FILE
#     c:\conda\lib\site-packages\pandas\core\__init__.py

# %%
students_performance_with_names["gender"]
# Out:
# Cersei        female
# Tywin           male
# Gregor          male
# Joffrey       female
# Ilyn Payne    female
# Name: gender, dtype: object

# %%
type(students_performance_with_names["gender"])
# Out:
# pandas.core.series.Series

# %%
students_performance_with_names[["gender"]]
# Out:
#             gender
# Cersei      female
# Tywin         male
# Gregor        male
# Joffrey     female
# Ilyn Payne  female

# %%
type(students_performance_with_names[["gender"]])
# Out:
# pandas.core.frame.DataFrame

# %%
#поведение в зависимости от типа данных будет разным, например:
students_performance_with_names[["gender"]].shape
# Out:
# (5, 1)

# %%
#И:
students_performance_with_names["gender"].shape
# Out:
# (5,)

# %%
#К первому вопросу в степе 1.4
#Какие способы позволяют отобрать 7 первых строк датафрэйма df
students_performance
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
#первый вариант ответа: df.head(7), проверим:
students_performance.head(7)
#правильно, вывелись первые 7
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
# 5  female        group B          associate's degree      standard
# 6  female        group B                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75
# ...

# %%
#второй вариант ответа: df.loc[:7], если индекс представляет собой последовательность чисел от 0 с шагом 1, проверим:
students_performance.loc[:7] # отобрались значения по индексам до 7, включая 7, то есть восемь первых строчек датафрейма
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
# 5  female        group B          associate's degree      standard
# 6  female        group B                some college      standard
# 7    male        group B                some college  free/reduced
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# ...

# %%
#df.iloc[:7], должно быть правильно, проверим
students_performance.iloc[:7]
#Да, верно
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
# 5  female        group B          associate's degree      standard
# 6  female        group B                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75
# ...

# %%
#df.loc[:6], если индекс представляет собой последовательность чисел от 0 с шагом 1
students_performance.loc[:6]
#верно
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
# 5  female        group B          associate's degree      standard
# 6  female        group B                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75
# ...

# %%
#df.iloc[0:7]
students_performance.iloc[0:7]
#верно
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
# 5  female        group B          associate's degree      standard
# 6  female        group B                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75
# ...

# %%
#df.tail(7)
students_performance.tail(7)
#не верно
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 993  female        group D           bachelor's degree  free/reduced
# 994    male        group A                 high school      standard
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# 993                    none          62             72             74
# 994                    none          63             63             62
# 995               completed          88             99             95
# 996                    none          62             55             55
# ...

# %%
#МЕТОДЫ




#df.dtypes - "Return the dtypes in the DataFrame." - возвращает серию с описанием типа каждой колонки
print(students_performance.dtypes)
print(type(students_performance.dtypes))
# Out:
# gender                         object
# race/ethnicity                 object
# parental level of education    object
# lunch                          object
# test preparation course        object
# math score                      int64
# reading score                   int64
# writing score                   int64
# dtype: object
# <class 'pandas.core.series.Series'>

# %%
#df.size - "Return an int representing the number of elements in this object." - возвращает число ячеек (число строк, умноженное на число столбцов) в df
print(students_performance.size)
print(type(students_performance.size))
# Out:
# 8000
# <class 'numpy.int32'>

# %%
#df.columns - "The column labels of the DataFrame." - возвращает коллекцию с названиями колонок
print(students_performance.columns)
print(type(students_performance.columns))
# Out:
# Index(['gender', 'race/ethnicity', 'parental level of education', 'lunch',
#        'test preparation course', 'math score', 'reading score',
#        'writing score'],
#       dtype='object')
# <class 'pandas.core.indexes.base.Index'>

# %%
#df.index - "The index (row labels) of the DataFrame." - возвращает коллекцию с индексом всех строк
students_performance.index
# Out:
# RangeIndex(start=0, stop=1000, step=1)

# %%
#df.shape - "Return a tuple representing the dimensionality of the DataFrame." Возвращает коллекцию с индексом всех строк.
students_performance.shape
# Out:
# (1000, 8)

# %%
# #Задача на титаник.
# А теперь используем эти методы на знаменитом титаническом датасэте! Загрузите датасэт, посмотрите на датафрэйм и ответьте на вопросы
#
# Комментарий: в ответе необходимо указать количество колонок.
#
#
# Число колонок в представленном датафрэйме
#  , а число строк
#  Тип float имеют
#  колонки, int -
#  , и object

# %%
titanic = pd.read_csv("E:\code\studies\karpov_intro_ml\\titanic.csv")
titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
#Число колонок в представленном датафрэйме.
(titanic.shape)[1]
# Out:
# 12

# %%
#Число строк
(titanic.shape)[0]
# Out:
# 891

# %%
#Число колонок типа float
((titanic.select_dtypes(include = float)).shape)[1]
# Out:
# 2

# %%
#Число колонок типа int
titanic.dtypes[titanic.dtypes=='int64'].count()
# Out:
# 5

# %%
#Число колонок типа object
((titanic.select_dtypes(include = object)).shape)[1]
# Out:
# 5

# %%
#Фильтрация данных, для примера отберём только те наблюдения, где gender = female
students_performance.gender #-Pandas.Series
# Out:
# 0      female
# 1      female
# 2      female
# 3        male
# 4        male
#         ...
# 995    female
# 996      male
# 997    female
# 998    female
# 999    female
# Name: gender, Length: 1000, dtype: object

# %%
students_performance.gender == "female"
# Out:
# 0       True
# 1       True
# 2       True
# 3      False
# 4      False
#        ...
# 995     True
# 996    False
# 997     True
# 998     True
# 999     True
# Name: gender, Length: 1000, dtype: bool

# %%
students_performance.loc[students_performance.gender == "female"]
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 5    female        group B          associate's degree      standard
# 6    female        group B                some college      standard
# ..      ...            ...                         ...           ...
# 993  female        group D           bachelor's degree  free/reduced
# 995  female        group E             master's degree      standard
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
students_performance.loc[students_performance.gender == "female"]
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 5    female        group B          associate's degree      standard
# 6    female        group B                some college      standard
# ..      ...            ...                         ...           ...
# 993  female        group D           bachelor's degree  free/reduced
# 995  female        group E             master's degree      standard
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
students_performance.loc[students_performance.gender == "female" , ["math score", "writing score"]]
# Out:
#      math score  writing score
# 0            72             74
# 1            69             88
# 2            90             93
# 5            71             78
# 6            88             92
# ..          ...            ...
# 993          62             74
# 995          88             95
# 997          59             65
# 998          68             77
# 999          77             86
#
# [518 rows x 2 columns]

# %%
#можно и без loc
students_performance[students_performance.gender == "female"]
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 5    female        group B          associate's degree      standard
# 6    female        group B                some college      standard
# ..      ...            ...                         ...           ...
# 993  female        group D           bachelor's degree  free/reduced
# 995  female        group E             master's degree      standard
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
# теперь отберём  наблюдения, где writing score больше среднего значения
mean_writing_score = students_performance["writing score"].mean() #среднее значение переменном writing score

# %%
students_performance[students_performance["writing score"] > mean_writing_score] #done
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 4      male        group C                some college      standard
# 5    female        group B          associate's degree      standard
# ..      ...            ...                         ...           ...
# 992  female        group D          associate's degree  free/reduced
# 993  female        group D           bachelor's degree  free/reduced
# 995  female        group E             master's degree      standard
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
students_performance[(students_performance['writing score'] > 99) & (students_performance.gender == 'female')]
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 106  female        group D             master's degree      standard
# 114  female        group E           bachelor's degree      standard
# 165  female        group C           bachelor's degree      standard
# 179  female        group D            some high school      standard
# 377  female        group D             master's degree  free/reduced
# 403  female        group D                 high school      standard
# 458  female        group E           bachelor's degree      standard
# 566  female        group E           bachelor's degree  free/reduced
# 685  female        group E             master's degree      standard
# 903  female        group D           bachelor's degree  free/reduced
# 957  female        group D             master's degree      standard
# 962  female        group E          associate's degree      standard
# 970  female        group D           bachelor's degree      standard
#
# ...

# %%
#задача
# У какой доли студентов из датасэта в колонке lunch указано free/reduced?
#
# Формат ответа десятичная дробь, например, 0.25

# %%
((students_performance[(students_performance['lunch']) == "free/reduced"]).shape[0])/len(students_performance)
# Out:
# 0.355

# %%
#или
students_performance.lunch.value_counts(normalize=True).loc['free/reduced']
# Out:
# 0.355

# %%
#Как различается среднее и дисперсия оценок по предметам у групп студентов со стандартным или урезанным ланчем?
free_lunch_students = students_performance.loc[students_performance.lunch == "free/reduced" , ["math score", "writing score", "reading score"]]
standard_lunch_students = students_performance.loc[students_performance.lunch == "standard" , ["math score", "writing score", "reading score"]]

# %%
#Средние оценки групп студентов с урезанным ланчем:
print("письмо студентов с урезанным ланчем - "+ str(free_lunch_students["writing score"].mean()))
print("математика студентов с урезанным ланчем - " + str(free_lunch_students["math score"].mean()))
print("чтение студентов с урезанным ланчем - " + str(free_lunch_students["reading score"].mean()))
# Out:
# письмо студентов с урезанным ланчем - 63.02253521126761
# математика студентов с урезанным ланчем - 58.92112676056338
# чтение студентов с урезанным ланчем - 64.65352112676057

# %%
#Средние оценки групп студентов с полным ланчем:
print("письмо студентов с полным ланчем - "+ str(standard_lunch_students["writing score"].mean()))
print("математика студентов с полным ланчем - " + str(standard_lunch_students["math score"].mean()))
print("чтение студентов с полным ланчем - " + str(standard_lunch_students["reading score"].mean()))
# Out:
# письмо студентов с полным ланчем - 70.8232558139535
# математика студентов с полным ланчем - 70.03410852713178
# чтение студентов с полным ланчем - 71.65426356589147

# %%
#Дисперсия групп студентов с урезанным ланчем:
print("дисперсия письмо студентов с урезанным ланчем - "+ str(free_lunch_students["writing score"].var()))
print("дисперсия математика студентов с урезанным ланчем - " + str(free_lunch_students["math score"].var()))
print("дисперсия чтение студентов с урезанным ланчем - " + str(free_lunch_students["reading score"].var()))
# Out:
# дисперсия письмо студентов с урезанным ланчем - 238.20288056019737
# дисперсия математика студентов с урезанным ланчем - 229.8242699132649
# дисперсия чтение студентов с урезанным ланчем - 221.8711386965864

# %%
#Дисперсия групп студентов с полным ланчем:
print("дисперсия письмо студентов с полным ланчем - "+ str(standard_lunch_students["writing score"].var()))
print("дисперсия математика студентов с полным ланчем - " + str(standard_lunch_students["math score"].var()))
print("дисперсия чтение студентов с полным ланчем - " + str(standard_lunch_students["reading score"].var()))
# Out:
# дисперсия письмо студентов с полным ланчем - 205.62088689874332
# дисперсия математика студентов с полным ланчем - 186.41808946025324
# дисперсия чтение студентов с полным ланчем - 191.28556020992812

# %%
students_performance.groupby('lunch').mean().round(3) # или так LOL, опять я хуйету какую то писал
# Out:
#               math score  reading score  writing score
# lunch
# free/reduced      58.921         64.654         63.023
# standard          70.034         71.654         70.823

# %%
students_performance.groupby('lunch').var().round(3)
# Out:
#               math score  reading score  writing score
# lunch
# free/reduced     229.824        221.871        238.203
# standard         186.418        191.286        205.621

# %%
#Переименуем колонки с пробелами для удобства обращения к ним через df.
students_performance = students_performance.rename(columns= {"parental level of education" : "parental_level_of_education", "test preparation course" : "test_preparation_course" , "math score" : "math_score" , "reading score" : "reading_score" , "writing score" : "writing_score"})

# %%
students_performance.query("writing_score > 80")
# Out:
#      gender race/ethnicity parental_level_of_education         lunch  \
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 6    female        group B                some college      standard
# 16     male        group C                 high school      standard
# 34     male        group E                some college      standard
# ..      ...            ...                         ...           ...
# 983  female        group A                some college      standard
# 984  female        group C            some high school      standard
# 989  female        group D                some college  free/reduced
# 995  female        group E             master's degree      standard
# 999  female        group D                some college  free/reduced
#
#     test_preparation_course  math_score  reading_score  writing_score
# ...

# %%
students_performance.query("gender == 'female'")
# Out:
#      gender race/ethnicity parental_level_of_education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 5    female        group B          associate's degree      standard
# 6    female        group B                some college      standard
# ..      ...            ...                         ...           ...
# 993  female        group D           bachelor's degree  free/reduced
# 995  female        group E             master's degree      standard
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test_preparation_course  math_score  reading_score  writing_score
# ...

# %%
students_performance.query("gender == 'female' & math_score > 70 ")
# Out:
#      gender race/ethnicity parental_level_of_education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 2    female        group B             master's degree      standard
# 5    female        group B          associate's degree      standard
# 6    female        group B                some college      standard
# 36   female        group D          associate's degree      standard
# ..      ...            ...                         ...           ...
# 979  female        group C          associate's degree      standard
# 983  female        group A                some college      standard
# 984  female        group C            some high school      standard
# 995  female        group E             master's degree      standard
# 999  female        group D                some college  free/reduced
#
#     test_preparation_course  math_score  reading_score  writing_score
# ...

# %%
math_score_query = 70
students_performance.query("gender == 'female' & @math_score_query < math_score ") # переменная в строке вызывается через @
# Out:
#      gender race/ethnicity parental_level_of_education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 2    female        group B             master's degree      standard
# 5    female        group B          associate's degree      standard
# 6    female        group B                some college      standard
# 36   female        group D          associate's degree      standard
# ..      ...            ...                         ...           ...
# 979  female        group C          associate's degree      standard
# 983  female        group A                some college      standard
# 984  female        group C            some high school      standard
# 995  female        group E             master's degree      standard
# 999  female        group D                some college  free/reduced
#
#     test_preparation_course  math_score  reading_score  writing_score
# ...

# %%
# Ещё можно вот так от пробелов избавиться:(из комментов на степике)
# students_performance.columns = [x.replace(" ", "_") for x in students_performance.columns]

# %%
#отберем из нашего дф, дф только со скорами
score_columns = [i for i in list(students_performance) if "score" in i] # создадим список из имён колонок со словом скоре в составе

# %%
score_columns
# Out:
# ['math_score', 'reading_score', 'writing_score']

# %%
students_performance[score_columns].head()
# Out:
#    math_score  reading_score  writing_score
# 0          72             72             74
# 1          69             90             88
# 2          90             95             93
# 3          47             57             44
# 4          76             78             75

# %%
#метод проще или пандас уэй это df.filter
students_performance.filter(like = "score")
# Out:
#      math_score  reading_score  writing_score
# 0            72             72             74
# 1            69             90             88
# 2            90             95             93
# 3            47             57             44
# 4            76             78             75
# ..          ...            ...            ...
# 995          88             99             95
# 996          62             55             55
# 997          59             71             65
# 998          68             78             77
# 999          77             86             86
#
# [1000 rows x 3 columns]

# %%
#ещё пример на фильтер, используя нащ играпрестольный датасет
students_performance_with_names.filter(like = "e", axis = 0) #axis = 0 значит что фильтр применился к названию строк, axis = 1 значит что для столбцов, ну и по умолчанию он равен 1
# Out:
#             gender race/ethnicity parental level of education     lunch  \
# Cersei      female        group B           bachelor's degree  standard
# Gregor        male        group C                some college  standard
# Joffrey     female        group B          associate's degree  standard
# Ilyn Payne  female        group B                some college  standard
#
#            test preparation course  math score  reading score  writing score
# Cersei                        none          72             72             74
# Gregor                        none          76             78             75
# Joffrey                       none          71             83             78
# Ilyn Payne               completed          88             95             92

# %%
#Фильтр - очень даже, если его скрестить с ручными питоном!  Вот, например, он имеет еще метод items для чисел, можно отобрать еще и четные  строки.

#df.filter(like= 'score').filter(items = (i for i in range(len(df)) if i % 2 == 0), axis = 0)

# %%
# Аргумент axis отвечает за то, какие лэйблы мы рассматриваем - индекс или колонки
#
# Аргумент like отбирает те лэйблы, где встречается поданное значение
#
# Можно использовать только один из аргументов items, like, regex
#
# Аргумент items отбирает лэйблы, переданные в коллекции в качестве значения
#
# Аргумент regex отбирает лэйблы, подходящие к переданному паттерну

# %%
#1_6 groupby and aggregate

# %%
students_performance.head(5)
# Out:
#    gender race/ethnicity parental_level_of_education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test_preparation_course  math_score  reading_score  writing_score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
#Посчитаем среднее значение скоров в зависимости от пола студентов
students_performance.groupby("gender").mean()
# Out:
#         math_score  reading_score  writing_score
# gender
# female   63.633205      72.608108      72.467181
# male     68.728216      65.473029      63.311203

# %%
students_performance.groupby("gender").aggregate({"math_score" : "mean"})
# Out:
#         math_score
# gender
# female   63.633205
# male     68.728216

# %%
students_performance.groupby("gender").aggregate({"math_score" : "mean", "reading_score" : "mean"})
# Out:
#         math_score  reading_score
# gender
# female   63.633205      72.608108
# male     68.728216      65.473029

# %%
students_performance.groupby("gender", as_index = False).aggregate({"math_score" : "mean", "reading_score" : "mean"}).rename(columns = {"math_score" : "mean_math_score", "reading_score" : "mean_reading_score"})
# Out:
#    gender  mean_math_score  mean_reading_score
# 0  female        63.633205           72.608108
# 1    male        68.728216           65.473029

# %%
# Кстати, если подавать значения для ключей в виде списка, то можно, во-первых, выводить несколько статистик для одной переменной, а, во-вторых, колонки будут иметь названия в соответствии со статистикой.
# Вот такой код

students_performance.groupby('gender', as_index=False).aggregate({'math_score': ['mean', 'count', 'std'],'reading_score': ['std', 'min', 'max']})
# Даст такой результат:
# Out:
#    gender math_score                  reading_score
#                 mean count        std           std min  max
# 0  female  63.633205   518  15.491453     14.378245  17  100
# 1    male  68.728216   482  14.356277     13.931832  23  100

# %%
#Ничего не мешает группировать по нескольким переменным, нужно обернуть используемые переменные в список
students_performance.groupby(["gender", "race/ethnicity"], as_index = False).aggregate({"math_score" : "mean", "reading_score" : "mean"}).rename(columns = {"math_score" : "mean_math_score", "reading_score" : "mean_reading_score"})
#ПРИКОООООЛЬНО)
# Out:
#    gender race/ethnicity  mean_math_score  mean_reading_score
# 0  female        group A        58.527778           69.000000
# 1  female        group B        61.403846           71.076923
# 2  female        group C        62.033333           71.944444
# 3  female        group D        65.248062           74.046512
# 4  female        group E        70.811594           75.840580
# 5    male        group A        63.735849           61.735849
# 6    male        group B        65.930233           62.848837
# 7    male        group C        67.611511           65.424460
# 8    male        group D        69.413534           66.135338
# 9    male        group E        76.746479           70.295775

# %%
mean_score = students_performance.groupby(["gender", "race/ethnicity"]).aggregate({"math_score" : "mean", "reading_score" : "mean"}).rename(columns = {"math_score" : "mean_math_score", "reading_score" : "mean_reading_score"})
mean_score.index #мультииндекс
# Out:
# MultiIndex([('female', 'group A'),
#             ('female', 'group B'),
#             ('female', 'group C'),
#             ('female', 'group D'),
#             ('female', 'group E'),
#             (  'male', 'group A'),
#             (  'male', 'group B'),
#             (  'male', 'group C'),
#             (  'male', 'group D'),
#             (  'male', 'group E')],
#            names=['gender', 'race/ethnicity'])

# %%
mean_score.loc[("female", "group A")]
# Out:
# mean_math_score       58.527778
# mean_reading_score    69.000000
# Name: (female, group A), dtype: float64

# %%
students_performance.math_score.unique() #уникальные значения
# Out:
# array([ 72,  69,  90,  47,  76,  71,  88,  40,  64,  38,  58,  65,  78,
#         50,  18,  46,  54,  66,  44,  74,  73,  67,  70,  62,  63,  56,
#         97,  81,  75,  57,  55,  53,  59,  82,  77,  33,  52,   0,  79,
#         39,  45,  60,  61,  41,  49,  30,  80,  42,  27,  43,  68,  85,
#         98,  87,  51,  99,  84,  91,  83,  89,  22, 100,  96,  94,  48,
#         35,  34,  86,  92,  37,  28,  24,  26,  95,  36,  29,  32,  93,
#         19,  23,   8], dtype=int64)

# %%
students_performance.math_score.nunique() #число уникальных значений
# Out:
# 81

# %%
#количество уникальных скоров на пересечении групп
students_performance.groupby(["gender", "race/ethnicity"]).math_score.nunique()
# Out:
# gender  race/ethnicity
# female  group A           29
#         group B           51
#         group C           59
#         group D           53
#         group E           44
# male    group A           38
#         group B           43
#         group C           56
#         group D           49
#         group E           38
# Name: math_score, dtype: int64

# %%
#отберём по пять лучших студентов по математике по переменной gender:
students_performance.sort_values(["gender", "math_score"], ascending=False).groupby("gender").head(5)
# Out:
#      gender race/ethnicity parental_level_of_education         lunch  \
# 149    male        group E          associate's degree  free/reduced
# 623    male        group A                some college      standard
# 625    male        group D                some college      standard
# 916    male        group E           bachelor's degree      standard
# 306    male        group E                some college      standard
# 451  female        group E                some college      standard
# 458  female        group E           bachelor's degree      standard
# 962  female        group E          associate's degree      standard
# 114  female        group E           bachelor's degree      standard
# 263  female        group E                 high school      standard
#
#     test_preparation_course  math_score  reading_score  writing_score
# 149               completed         100            100             93
# ...

# %%
# Если хочется отсортировать, например, в порядке возрастания по одной переменной, и в порядке убывания по другой, то достаточно лишь передать в аргумент ascending соответствующий лист:
#
# df.sort_values(['gender', 'math_score'], ascending=[True, False])

# %%
#как создать новую колонку в дф
students_performance["total_score"] = students_performance.math_score + students_performance.reading_score + students_performance.writing_score

# %%
students_performance.head()
# Out:
#    gender race/ethnicity parental_level_of_education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test_preparation_course  math_score  reading_score  writing_score  \
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75
#
#    total_score
# 0          218
# 1          247
# 2          278
# 3          148
# 4          229

# %%
students_performance = students_performance.assign(total_score_log = np.log(students_performance.total_score)) #assign позволяет добавлять несколько колонок за раз

# %%
students_performance.head()
# Out:
#    gender race/ethnicity parental_level_of_education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test_preparation_course  math_score  reading_score  writing_score  \
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75
#
#    total_score  total_score_log
# 0          218         5.384495
# 1          247         5.509388
# 2          278         5.627621
# ...

# %%
#удаление колонки
students_performance.drop(["total_score"], axis=1)
# Out:
#      gender race/ethnicity parental_level_of_education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test_preparation_course  math_score  reading_score  writing_score  \
# ...

# %%
# Можно просуммировать несколько колонок так (вдруг у нас 50 скоров?):
#
# df.filter(like = 'score').sum(axis=1)
#
# C фильтром уже знакомы, а sum(axis=1) суммирует колонки построчно, а не строки по колонкам, как стоит по умолчанию (axis=0, результатом этой операции стало бы):
# math_score        66089
# reading_score     69169
# writing_score     68054

# %%
#Пересчитаем число ног у героев игры Dota2! Сгруппируйте героев из датасэта по числу их ног (колонка legs), и заполните их число в задании ниже.

# Данные взяты отсюда, на этом же сайте можно найти больше разнообразных данных по Dota2.

# %%
dota_hero.groupby('legs').agg({"legs" : "count"})
# Out:
#       legs
# legs
# 0       11
# 2       95
# 4        7
# 6        3
# 8        1

# %%
#ёеще варианты
dota_hero.groupby('legs').size()
# Out:
# legs
# 0    11
# 2    95
# 4     7
# 6     3
# 8     1
# dtype: int64

# %%
# К нам поступили данные из бухгалтерии о заработках Лупы и Пупы за разные задачи! Посмотрите у кого из них больше средний заработок в различных категориях (колонка Type) и заполните таблицу, указывая исполнителя с большим заработком в каждой из категорий.


lupa_pupa = pd.read_csv("E:\code\studies\karpov_intro_ml\\accountancy.csv")
lupa_pupa
# Out:
#     Unnamed: 0 Executor Type  Salary
# 0            0     Pupa    D      63
# 1            1     Pupa    A     158
# 2            2     Pupa    D     194
# 3            3     Pupa    E     109
# 4            4    Loopa    E     184
# 5            5    Loopa    F     232
# 6            6    Loopa    B     249
# 7            7     Pupa    F     195
# 8            8     Pupa    A     115
# 9            9     Pupa    E      65
# 10          10    Loopa    C     145
# 11          11    Loopa    D     149
# 12          12    Loopa    B      50
# 13          13     Pupa    A     217
# 14          14    Loopa    D     110
# 15          15     Pupa    F      62
# 16          16     Pupa    A      55
# 17          17    Loopa    B     190
# 18          18    Loopa    E      83
# 19          19     Pupa    A     234
# 20          20    Loopa    E     156
# 21          21    Loopa    E     219
# 22          22     Pupa    C      55
# 23          23     Pupa    D     144
# ...

# %%
lupa_pupa.groupby(["Type", "Executor"]).Salary.mean() # я топыч
# Out:
# Type  Executor
# A     Loopa        58.000000
#       Pupa        160.833333
# B     Loopa       145.166667
#       Pupa         77.000000
# C     Loopa       154.333333
#       Pupa         74.500000
# D     Loopa       137.714286
#       Pupa        146.500000
# E     Loopa       164.000000
#       Pupa        131.200000
# F     Loopa       238.000000
#       Pupa        136.250000
# Name: Salary, dtype: float64

# %%
#Продолжим исследование героев Dota2. Сгруппируйте по колонкам attack_type и primary_attr и выберите самый распространённый набор характеристик.
dota_hero.head(5)
# Out:
#    Unnamed: 0 attack_type  id  legs  localized_name  \
# 0           0       Melee   1     2       Anti-Mage
# 1           1       Melee   2     2             Axe
# 2           2      Ranged   3     4            Bane
# 3           3       Melee   4     2     Bloodseeker
# 4           4      Ranged   5     2  Crystal Maiden
#
#                            name primary_attr  \
# 0        npc_dota_hero_antimage          agi
# 1             npc_dota_hero_axe          str
# 2            npc_dota_hero_bane          int
# 3     npc_dota_hero_bloodseeker          agi
# 4  npc_dota_hero_crystal_maiden          int
#
#                                                roles
# 0                       ['Carry', 'Escape', 'Nuker']
# 1    ['Initiator', 'Durable', 'Disabler', 'Jungler']
# 2        ['Support', 'Disabler', 'Nuker', 'Durable']
# 3  ['Carry', 'Disabler', 'Jungler', 'Nuker', 'Ini...
# 4        ['Support', 'Disabler', 'Nuker', 'Jungler']

# %%
dota_hero.groupby(["attack_type", "primary_attr"]).size()
# Out:
# attack_type  primary_attr
# Melee        agi             19
#              int              2
#              str             35
# Ranged       agi             18
#              int             40
#              str              3
# dtype: int64

# %%
# Аспирант Ростислав изучает метаболом водорослей и получил такую табличку. В ней он записал вид каждой водоросли, её род (группа, объединяющая близкие виды), группа (ещё одно объединение водорослей в крупные фракции) и концентрации анализируемых веществ.
#
# Помогите Ростиславу найти среднюю концентрацию каждого из веществ в каждом из родов (колонка genus)! Для этого проведите группировку датафрэйма, сохранённого в переменной concentrations, и примените метод, сохранив результат в переменной mean_concentrations.
#
# Модуль pandas уже импортирован.
seaweed = pd.read_csv("E:\code\studies\karpov_intro_ml\\algae.csv")
seaweed.head()
# Out:
#                species       genus  group   sucrose    alanin   citrate  \
# 0    Fucus_vesiculosus       Fucus  brown  3.001472  3.711498  5.004262
# 1  Saccharina_japonica  Saccharina  brown  6.731070  1.255251  5.621499
# 2       Fucus_serratus       Fucus  brown  3.276870  0.346431  1.216767
# 3      Fucus_distichus       Fucus  brown  6.786996  6.641303  6.423606
# 4    Cladophora_fracta  Cladophora  green  3.861470  1.648450  6.940588
#
#     glucose  oleic_acid
# 0  2.548459    6.405165
# 1  6.013219    4.156700
# 2  3.623225    0.304573
# 3  2.272724    3.393203
# 4  2.316955    2.528886

# %%
seaweed.groupby("genus").agg({'alanin': ["min", "mean", "max"]}).loc [["Fucus"]].round(2)
# Out:
#       alanin
#          min  mean   max
# genus
# Fucus   0.35  3.57  6.64

# %%
#или
seaweed.query("genus == 'Fucus'").describe()
# Out:
#         sucrose    alanin   citrate   glucose  oleic_acid
# count  3.000000  3.000000  3.000000  3.000000    3.000000
# mean   4.355112  3.566411  4.214878  2.814803    3.367647
# std    2.110570  3.149943  2.691679  0.713559    3.050376
# min    3.001472  0.346431  1.216767  2.272724    0.304573
# 25%    3.139171  2.028965  3.110515  2.410591    1.848888
# 50%    3.276870  3.711498  5.004262  2.548459    3.393203
# 75%    5.031933  5.176401  5.713934  3.085842    4.899184
# max    6.786996  6.641303  6.423606  3.623225    6.405165

# %%
seaweed.groupby('group').aggregate(['count', 'var', np.ptp])
# Out:
#       sucrose                     alanin                     citrate  \
#         count       var       ptp  count       var       ptp   count
# group
# brown       6  5.459098  5.189345      6  7.220351  6.294872       6
# green       3  2.672626  3.259662      3  7.059917  5.232574       3
# red         1       NaN  0.000000      1       NaN  0.000000       1
#
#                           glucose                     oleic_acid            \
#             var       ptp   count       var       ptp      count       var
# group
# brown  5.468942  5.351686       6  1.767756  3.740495          6  4.385233
# green  3.950113  3.857763       3  0.266265  1.026753          3  0.540388
# red         NaN  0.000000       1       NaN  0.000000          1       NaN
#
#
#             ptp
# group
# brown  6.100592
# green  1.396502
# red    0.000000

# %%
#или
seaweed.groupby('group').agg({'citrate': 'var', 'sucrose': lambda x: x.max() - x.min(), 'glucose': 'count'}).round(2)
# Out:
#        citrate  sucrose  glucose
# group
# brown     5.47     5.19        6
# green     3.95     3.26        3
# red        NaN     0.00        1
